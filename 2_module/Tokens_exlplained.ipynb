# %% [markdown]
# <a href="https://colab.research.google.com/github/harjeet88/A_For_Algorithms/blob/master/2_module/Tokens_exlplained.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using Transformers

# %%
# !pip install -q transformers

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-neo-125M")

text = "unbelievable transformations!"
tokens = tokenizer.tokenize(text)
tokens
# Out:
# ['un', 'bel', 'iev', 'able', 'Ġtransformations', '!']

# %% [markdown]
# # Open AI tikToken

# %%
# !pip install -q tiktoken

# %%
import tiktoken

tokenizer = tiktoken.get_encoding("cl100k_base")

# %%
text = "unbelievable transformations!"

# %%
tokens = tokenizer.encode(text)
decoded_tokens = [tokenizer.decode([t]) for t in tokens]

print("Tokens:", tokens)
print("Decoded pieces:", decoded_tokens)
# Out:
# Tokens: [403, 6667, 11203, 540, 38226, 0]
# Decoded pieces: ['un', 'bel', 'iev', 'able', ' transformations', '!']

# %% [markdown]
# #GPT 2 Tokenizer

# %%
from transformers import GPT2Tokenizer

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# %%
text = "unbelievable transformations!"
tokens = tokenizer.tokenize(text)

tokens
# Out:
# ['un', 'bel', 'iev', 'able', 'Ġtransformations', '!']
