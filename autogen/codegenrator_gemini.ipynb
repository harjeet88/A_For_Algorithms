# %% [markdown]
# <a href="https://colab.research.google.com/github/harjeet88/A_For_Algorithms/blob/master/autogen/codegenrator_gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/microsoft/autogen.git@v0.2.25
# Out:
# Collecting git+https://github.com/microsoft/autogen.git@v0.2.25
#   Cloning https://github.com/microsoft/autogen.git (to revision v0.2.25) to /tmp/pip-req-build-hax5uuwi
#   Running command git clone --filter=blob:none --quiet https://github.com/microsoft/autogen.git /tmp/pip-req-build-hax5uuwi
#   Running command git checkout -q 4ab8a884870f4aeafe3587c56169bb094061af5b
#   Encountered 1 file(s) that should have been pointers, but weren't:
#         website/static/img/gallery/autotx.png
#   Resolved https://github.com/microsoft/autogen.git to commit 4ab8a884870f4aeafe3587c56169bb094061af5b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: openai>=1.3 in /usr/local/lib/python3.11/dist-packages (from pyautogen==0.2.25) (1.91.0)
# Collecting diskcache (from pyautogen==0.2.25)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from pyautogen==0.2.25) (3.1.0)
# Collecting flaml (from pyautogen==0.2.25)
#   Downloading FLAML-2.3.5-py3-none-any.whl.metadata (16 kB)
# Collecting numpy<2,>=1.17.0 (from pyautogen==0.2.25)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.0 MB/s eta 0:00:00
# Collecting python-dotenv (from pyautogen==0.2.25)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (from pyautogen==0.2.25) (0.9.0)
# Requirement already satisfied: pydantic!=2.6.0,<3,>=1.10 in /usr/local/lib/python3.11/dist-packages (from pyautogen==0.2.25) (2.11.7)
# Collecting docker (from pyautogen==0.2.25)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.3->pyautogen==0.2.25) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.3->pyautogen==0.2.25) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.3->pyautogen==0.2.25) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.3->pyautogen==0.2.25) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.3->pyautogen==0.2.25) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai>=1.3->pyautogen==0.2.25) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai>=1.3->pyautogen==0.2.25) (4.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=2.6.0,<3,>=1.10->pyautogen==0.2.25) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=2.6.0,<3,>=1.10->pyautogen==0.2.25) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=2.6.0,<3,>=1.10->pyautogen==0.2.25) (0.4.1)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from docker->pyautogen==0.2.25) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from docker->pyautogen==0.2.25) (2.4.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken->pyautogen==0.2.25) (2024.11.6)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai>=1.3->pyautogen==0.2.25) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=1.3->pyautogen==0.2.25) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=1.3->pyautogen==0.2.25) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.3->pyautogen==0.2.25) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->docker->pyautogen==0.2.25) (3.4.2)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 88.3 MB/s eta 0:00:00
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.8 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 10.7 MB/s eta 0:00:00
# Downloading FLAML-2.3.5-py3-none-any.whl (322 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 22.8 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Building wheels for collected packages: pyautogen
#   Building wheel for pyautogen (pyproject.toml) ... done
#   Created wheel for pyautogen: filename=pyautogen-0.2.25-py3-none-any.whl size=257234 sha256=c78ddec7d7d9a8fe731ebacea7ddbda9607853f372e5d2ecd9dc9fff68d7921b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a6t_d7ku/wheels/9c/f5/06/fc5e348944b6b822424c6cb5d6bda8a51a21c8abdf855477de
# Successfully built pyautogen
# Installing collected packages: python-dotenv, numpy, diskcache, flaml, docker, pyautogen
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed diskcache-5.6.3 docker-7.1.0 flaml-2.3.5 numpy-1.26.4 pyautogen-0.2.25 python-dotenv-1.1.1

# %%
from google.colab import userdata

GOOGLE_API_KEY= userdata.get('GOOGLE_API_KEY')

# %%
import os

api_key = GOOGLE_API_KEY

# %%
input="""
use autogen to create an agentic AI solution in python. this solution should do following
1. given a stock it should do fundamental analysis and explain if the stock is worth investment
2. one of the agents should do technical analysis of stock to check various technical indicators like RSI, MCAD, elliot wave, 50 DMA, 200 DMA , super trend, price volume action and suggest wheather we should invest or not
3. if the stock is worth investment, system should suggest what is right entry level and exit level for stock.
4. use google llm model gemini-2.5-flash-lite-preview-06-17
5. consider using alternative for talib as installation is very tricky
6. sricktly make sure that autogen code that you generate to use google gemini model is right one to call and it should not be calling openai model internally
7. make sure each agent has access to data downloaded from yahoo finance
8. make sure talib installation is not an issue as i am going to run this in google collab
generate python code for this which i can directly run in jupyter notebook.
"""

gemini="gemini-2.5-flash-lite-preview-06-17"

# %%
import os
import autogen
from autogen import AssistantAgent, UserProxyAgent
from autogen.code_utils import  infer_lang
from google.colab import userdata

# Retrieve your API key securely stored as a secret
#api_key= userdata.get('GEMINI_API_KEY')

if not api_key:
  raise ValueError(f"KEY: '{api_key}' is invalid")

MAX_USER_REPLIES=5
INPUT_START_MESSAGE = input

# Define your model configuration
config_list_gemini = [
    {
        "model": gemini,
        "api_key": api_key,
        "api_type": "google"
    }
]


# Initialize the assistant agent with the Gemini model configuration
assistant = AssistantAgent(
    name="assistant",
    llm_config={
        "cache_seed": 41,
        "config_list": config_list_gemini,
        "seed": 42
    },
)

# Initialize the user proxy agent
try:
  user_proxy = UserProxyAgent(
    name="user_proxy",
    human_input_mode="NEVER",
    max_consecutive_auto_reply=MAX_USER_REPLIES,
    is_termination_msg=lambda x: x.get("content", "").rstrip().endswith("TERMINATE"),
    code_execution_config={
        "work_dir": "coding",
        "use_docker": False
    },
  )
except Exception as e:
  print(f"The following error happened: {str(e)}")
  exit()


# Start the chat between the user proxy and the assistant agent
chat_response = user_proxy.initiate_chat(
    assistant,
    message=INPUT_START_MESSAGE,
    # summary_method="reflection_with_llm",
)

chat_id = chat_response.chat_id
convs = chat_response.chat_history
total_cost = chat_response.cost[1]

print(f"CHAT REF: {chat_id}")
print(f"COST OF TRANSACTION: {total_cost}")

for conv in convs:
  content = conv['content']
  active_role = conv['role']

  print(f"{active_role}: {content}")


print("COMPLETE")
# Out:
# user_proxy (to assistant):
#
#
# use autogen to create an agentic AI solution in python. this solution should do following
# 1. given a stock it should do fundamental analysis and explain if the stock is worth investment
# 2. one of the agents should do technical analysis of stock to check various technical indicators like RSI, MCAD, elliot wave, 50 DMA, 200 DMA , super trend, price volume action and suggest wheather we should invest or not
# 3. if the stock is worth investment, system should suggest what is right entry level and exit level for stock.
# 4. use google llm model gemini-2.5-flash-lite-preview-06-17
# 5. consider using alternative for talib as installation is very tricky
# 6. sricktly make sure that autogen code that you generate to use google gemini model is right one to call and it should not be calling openai model internally
# 7. make sure each agent has access to data downloaded from yahoo finance
# 8. make sure talib installation is not an issue as i am going to run this in google collab
# generate python code for this which i can directly run in jupyter notebook.
#
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# Here's a plan to create an agentic AI solution for stock analysis using AutoGen and Google's Gemini model, addressing your specific requirements:
#
# **Plan:**
#
# 1.  **Setup Google Gemini API Key:** Obtain and set up your Google Gemini API key. This will be crucial for all agents interacting with the Gemini model.
# 2.  **Install necessary libraries:** Install `autogen`, `yfinance`, and a library for technical analysis that works well in Colab (alternatives to TA-Lib will be explored).
# 3.  **Define Agent Roles:**
#     *   **Data Fetcher Agent:** Downloads historical stock data from Yahoo Finance.
#     *   **Fundamental Analysis Agent:** Analyzes fundamental data and provides an investment recommendation based on it.
#     *   **Technical Analysis Agent:** Performs technical analysis using various indicators and provides a recommendation.
#     *   **Investment Strategy Agent:** Consolidates recommendations from both fundamental and technical agents, determines entry/exit levels if the stock is deemed investable, and provides a final recommendation.
# 4.  **Configure AutoGen Group Chat:** Set up a group chat with these agents, defining the order of interaction and how they communicate.
# 5.  **Implement Agent Logic:**
#     *   **Data Fetcher:** Use `yfinance` to download data for a given stock ticker.
#     *   **Fundamental Analysis:** Use Gemini to analyze downloaded fundamental data (e.g., P/E ratio, EPS, revenue growth, debt-to-equity) and provide a qualitative assessment.
#     *   **Technical Analysis:** Utilize a suitable Python library (like `pandas_ta`) for calculating technical indicators (RSI, MACD, Moving Averages, etc.). Then, use Gemini to interpret these indicators and suggest whether to invest.
#     *   **Investment Strategy:** Combine insights from both analyses. If both agree on investability, use Gemini to suggest entry and exit points based on the technical indicators and overall market sentiment.
# 6.  **Code Generation:** Provide the Python code that can be directly run in a Jupyter Notebook.
#
# **Exploring TA-Lib Alternatives for Google Colab:**
#
# TA-Lib can be challenging to install in environments like Google Colab. Here are good alternatives:
#
# *   **`pandas_ta`:** This is a very popular and easy-to-use technical analysis library that directly integrates with pandas DataFrames. It's generally straightforward to install in Colab.
# *   **`ta` (The Other TA library):** Another viable option that provides various technical indicators.
#
# For this solution, we will use `pandas_ta` due to its ease of installation and integration.
#
# Let's start by setting up the environment and defining the agents.
#
# ```python
# # filename: stock_analysis_autogen.py
# import autogen
# import yfinance as yf
# import pandas as pd
# import pandas_ta as ta
# import os
# import google.generativeai as genai
#
# # --- Configuration ---
# # Make sure to set your Google Gemini API key as an environment variable
# # export GOOGLE_API_KEY='YOUR_API_KEY'
# # Alternatively, you can paste your key directly here, but it's less secure.
# try:
#     GOOGLE_API_KEY = os.environ["GOOGLE_API_KEY"]
# except KeyError:
#     print("Please set the GOOGLE_API_KEY environment variable.")
#     # If you want to hardcode for testing (not recommended for production):
#     # GOOGLE_API_KEY = "YOUR_ACTUAL_GEMINI_API_KEY"
#     # exit() # Uncomment this line to exit if the key is not set
#
# genai.configure(api_key=GOOGLE_API_KEY)
#
# # Define the Gemini model
# GEMINI_MODEL = "gemini-2.5-flash-lite-preview-06-17"
#
# # --- Helper Function to Get Gemini Model ---
# def get_gemini_model():
#     """Returns a configured Gemini model for use by agents."""
#     try:
#         model = genai.GenerativeModel(GEMINI_MODEL)
#         return model
#     except Exception as e:
#         print(f"Error initializing Gemini model: {e}")
#         return None
#
# # --- Agent Definitions ---
#
# # User Proxy Agent
# user_proxy = autogen.UserProxyAgent(
#     name="User_Proxy",
#     system_message="A human admin. Interact with the user to solve the problem. If the user provides stock ticker, ask for confirmation and then pass it to the analysis team. When the final answer is ready, report it to the user.",
#     human_input_mode="NEVER", # Set to "ALWAYS" if you want manual intervention
#     llm_config={"config_list": [{"model": GEMINI_MODEL, "api_key": GOOGLE_API_KEY}]},
#     code_execution_config={"work_dir": "stock_analysis_output", "use_docker": False},
# )
#
# # Data Fetcher Agent
# data_fetcher = autogen.AssistantAgent(
#     name="Data_Fetcher",
#     system_message="You are responsible for fetching historical stock data from Yahoo Finance. "
#                    "You will receive a stock ticker and download its data for the last year. "
#                    "Save the data as a CSV file.",
#     llm_config={"config_list": [{"model": GEMINI_MODEL, "api_key": GOOGLE_API_KEY}]},
# )
#
# # Fundamental Analysis Agent
# fundamental_analyst = autogen.AssistantAgent(
#     name="Fundamental_Analyst",
#     system_message="You are a fundamental stock analyst. "
#                    "You will receive historical stock data (likely in CSV format). "
#                    "Analyze key financial metrics and provide an opinion on whether the stock is a good long-term investment. "
#                    "Focus on profitability, growth, valuation, and financial health. "
#                    "Use Gemini to help interpret the data and provide insights. "
#                    "Do not perform technical analysis. Output your findings clearly, including a recommendation (Invest/Do Not Invest/Hold) and a brief explanation.",
#     llm_config={"config_list": [{"model": GEMINI_MODEL, "api_key": GOOGLE_API_KEY}]},
# )
#
# # Technical Analysis Agent
# technical_analyst = autogen.AssistantAgent(
#     name="Technical_Analyst",
#     system_message="You are a technical stock analyst. "
#                    "You will receive historical stock data. "
#                    "Calculate and analyze key technical indicators: RSI, MACD, 50-day Moving Average (MA), 200-day MA, Supertrend, and Price/Volume action. "
#                    "Use the 'pandas_ta' library for calculations. "
#                    "Based on these indicators, provide a short-term to mid-term investment recommendation (Buy/Sell/Hold) and explain the reasoning. "
#                    "Focus on trends, momentum, and support/resistance levels. "
#                    "Use Gemini to help interpret the indicators and provide actionable insights. "
#                    "Do not perform fundamental analysis.",
#     llm_config={"config_list": [{"model": GEMINI_MODEL, "api_key": GOOGLE_API_KEY}]},
# )
#
# # Investment Strategy Agent
# investment_strategy_agent = autogen.AssistantAgent(
#     name="Investment_Strategy_Agent",
#     system_message="You are an investment strategist. "
#                    "You will receive the fundamental analysis and technical analysis reports for a stock. "
#                    "Based on both analyses, decide if the stock is worth investing in. "
#                    "If it is, suggest an appropriate entry level and exit level. "
#                    "If it's not worth investing, clearly state that. "
#                    "Your final output should be a consolidated investment recommendation with entry/exit points (if applicable) and a clear justification. "
#                    "Use Gemini to synthesize the information and provide strategic recommendations.",
#     llm_config={"config_list": [{"model": GEMINI_MODEL, "api_key": GOOGLE_API_KEY}]},
# )
#
# # --- Agent Communication and Workflow ---
#
# # Group Chat Manager
# # We will define the workflow here:
# # 1. User provides ticker to User_Proxy.
# # 2. User_Proxy asks for confirmation and passes ticker to Data_Fetcher.
# # 3. Data_Fetcher downloads data and saves it.
# # 4. Data_Fetcher informs User_Proxy about the saved file.
# # 5. User_Proxy then initiates the analysis by sending the file path to both Fundamental_Analyst and Technical_Analyst.
# # 6. Both analysts perform their respective analyses.
# # 7. Once both analyses are complete, User_Proxy sends both reports to the Investment_Strategy_Agent.
# # 8. Investment_Strategy_Agent provides the final consolidated report.
#
# # Let's define the chat.
# # The agents will communicate through the user_proxy as the orchestrator.
#
# # A simple workflow where agents speak sequentially or in parallel as needed.
# # For a more complex workflow, you might need to design a custom manager or use agent routing.
#
# # Let's try a simple group chat setup where User_Proxy orchestrates.
#
# # Initializing the group chat will require a list of agents and a specified initiator.
# # We need to define how agents will hand off tasks. This is typically done by having an agent
# # "reply" to another agent with a specific message, which the recipient agent then processes.
#
# # For this scenario, we'll make the User_Proxy the central point of communication.
# # The User_Proxy will forward messages to the appropriate agents.
#
# # --- Main execution logic ---
#
# def analyze_stock(stock_ticker):
#     print(f"Starting analysis for stock: {stock_ticker}")
#
#     # --- Task 1: Fetch Data ---
#     # User_Proxy initiates data fetching.
#     user_proxy.initiate_chat(
#         data_fetcher,
#         message=f"Please download historical data for stock ticker: {stock_ticker} for the last year and save it as a CSV file. "
#                 "Once done, inform me about the file name and location.",
#         summary_method="last", # Get the last message as summary
#     )
#
#     # After data fetching, the data_fetcher should have saved a file.
#     # We need to simulate or ensure the data_fetcher's output is accessible.
#     # Let's assume the data_fetcher saves it to 'stock_analysis_output/<ticker>_data.csv'
#     data_file_path = os.path.join("stock_analysis_output", f"{stock_ticker.upper()}_data.csv")
#     if not os.path.exists(data_file_path):
#         print(f"Error: Data file not found at {data_file_path}. Analysis cannot proceed.")
#         return
#
#     print(f"Data fetched and saved to: {data_file_path}")
#
#     # --- Task 2: Fundamental and Technical Analysis (Parallel execution) ---
#     # User_Proxy initiates both analyses concurrently by sending the data file path.
#
#     # Send data to Fundamental Analyst
#     user_proxy.initiate_chat(
#         fundamental_analyst,
#         message=f"Please perform fundamental analysis on the stock data provided in the file: {data_file_path}. "
#                 "Output your findings and investment recommendation.",
#         summary_method="last",
#         silent=True # Suppress output from individual agent chats if desired
#     )
#     fundamental_report = user_proxy.last_message(fundamental_analyst) # Get the last message from fundamental_analyst
#
#     # Send data to Technical Analyst
#     user_proxy.initiate_chat(
#         technical_analyst,
#         message=f"Please perform technical analysis on the stock data provided in the file: {data_file_path}. "
#                 "Calculate RSI, MACD, 50/200 DMA, Supertrend, and Price/Volume action. "
#                 "Provide your investment recommendation and reasoning.",
#         summary_method="last",
#         silent=True # Suppress output from individual agent chats if desired
#     )
#     technical_report = user_proxy.last_message(technical_analyst) # Get the last message from technical_analyst
#
#     # --- Task 3: Consolidate and Strategize ---
#     # User_Proxy sends both reports to the Investment Strategy Agent.
#     combined_analysis_message = f"Here are the analysis reports:\n\n" \
#                                 f"**Fundamental Analysis Report:**\n{fundamental_report}\n\n" \
#                                 f"**Technical Analysis Report:**\n{technical_report}\n\n" \
#                                 f"Please consolidate these findings and provide a final investment strategy, including entry and exit levels if the stock is deemed investable."
#
#     user_proxy.initiate_chat(
#         investment_strategy_agent,
#         message=combined_analysis_message,
#         summary_method="last",
#     )
#     final_recommendation = user_proxy.last_message(investment_strategy_agent)
#
#     print("\n" + "="*50)
#     print("FINAL INVESTMENT RECOMMENDATION:")
#     print(final_recommendation)
#     print("="*50)
#
# # --- Example Usage ---
# # You can call the analyze_stock function with a ticker symbol.
# # For example:
# # analyze_stock("AAPL")
#
# # To run this in Jupyter, you would execute the cell containing this code,
# # and then call analyze_stock("YOUR_TICKER_HERE").
#
# # Example of how to trigger the analysis from the user proxy directly for an interactive session
# # In a real notebook, you'd run this cell and then input the ticker.
# # For this script, we'll prompt the user for a ticker.
#
# if __name__ == "__main__":
#     print("Welcome to the Autogen Stock Analysis Tool!")
#     stock_to_analyze = input("Please enter the stock ticker you want to analyze (e.g., AAPL, MSFT, GOOG): ").strip().upper()
#     if stock_to_analyze:
#         analyze_stock(stock_to_analyze)
#     else:
#         print("No stock ticker provided. Exiting.")
#
# ```
#
# **Explanation and How to Use in Jupyter:**
#
# 1.  **Prerequisites:**
#     *   **Google Gemini API Key:** You need to obtain an API key from Google AI Studio.
#     *   **Environment Variable:** It's highly recommended to set your API key as an environment variable named `GOOGLE_API_KEY`.
#         *   In a Colab notebook, you can do this in a code cell *before* running the main script:
#             ```python
#             # filename: setup_api.py
#             import os
#             os.environ["GOOGLE_API_KEY"] = "YOUR_ACTUAL_GEMINI_API_KEY"
#             print("GOOGLE_API_KEY set.")
#             ```
#             **Replace `"YOUR_ACTUAL_GEMINI_API_KEY"` with your actual key.**
#     *   **Install Libraries:** Run the following in a Colab code cell:
#         ```bash
#         !pip install autogen yfinance pandas pandas_ta google-generativeai
#         ```
#
# 2.  **Code Structure:**
#     *   **Configuration:** Sets up the API key and the Gemini model to be used.
#     *   **Agent Definitions:**
#         *   `User_Proxy`: Acts as the orchestrator and interfaces with you.
#         *   `Data_Fetcher`: Downloads stock data using `yfinance`.
#         *   `Fundamental_Analyst`: Analyzes fundamental aspects.
#         *   `Technical_Analyst`: Performs technical analysis using `pandas_ta`.
#         *   `Investment_Strategy_Agent`: Consolidates and provides the final recommendation.
#     *   **`analyze_stock(stock_ticker)` Function:** This is the main workflow function.
#         *   It first calls the `Data_Fetcher` to get the data.
#         *   Then, it initiates parallel chats for `Fundamental_Analyst` and `Technical_Analyst` with the fetched data.
#         *   Finally, it sends the reports from both analysts to the `Investment_Strategy_Agent` for a consolidated output.
#     *   **Main Execution Block (`if __name__ == "__main__":`)**: This part allows you to run the script directly. It prompts you for a stock ticker.
#
# 3.  **Running in Jupyter Notebook:**
#
#     *   **Cell 1: Install Libraries:**
#         ```python
#         # filename: install_libs.py
#         !pip install autogen yfinance pandas pandas_ta google-generativeai
#         ```
#         Run this cell first.
#
#     *   **Cell 2: Set API Key:**
#         ```python
#         # filename: setup_api.py
#         import os
#         # IMPORTANT: Replace "YOUR_ACTUAL_GEMINI_API_KEY" with your actual Gemini API key
#         os.environ["GOOGLE_API_KEY"] = "YOUR_ACTUAL_GEMINI_API_KEY"
#         print("GOOGLE_API_KEY set.")
#         ```
#         Run this cell, replacing the placeholder with your key.
#
#     *   **Cell 3: Autogen Stock Analysis Code:**
#         ```python
#         # filename: stock_analysis_autogen.py
#         import autogen
#         import yfinance as yf
#         import pandas as pd
#         import pandas_ta as ta
#         import os
#         import google.generativeai as genai
#
#         # --- Configuration ---
#         try:
#             GOOGLE_API_KEY = os.environ["GOOGLE_API_KEY"]
#         except KeyError:
#             print("GOOGLE_API_KEY environment variable not set. Please set it.")
#             # exit() # In a notebook, this won't exit the whole notebook, just this cell.
#             # It's better to ensure it's set in a previous cell.
#             GOOGLE_API_KEY = None # Set to None if not found, agents might fail gracefully
#
#         genai.configure(api_key=GOOGLE_API_KEY)
#
#         # Define the Gemini model
#         GEMINI_MODEL = "gemini-2.5-flash-lite-preview-06-17"
#
#         # --- Agent Definitions ---
#
#         user_proxy = autogen.UserProxyAgent(
#             name="User_Proxy",
#             system_message="A human admin. Interact with the user to solve the problem. If the user provides stock ticker, ask for confirmation and then pass it to the analysis team. When the final answer is ready, report it to the user.",
#             human_input_mode="NEVER",
#             llm_config={"config_list": [{"model": GEMINI_MODEL, "api_key": GOOGLE_API_KEY}]},
#             code_execution_config={"work_dir": "stock_analysis_output", "use_docker": False},
#         )
#
#         data_fetcher = autogen.AssistantAgent(
#             name="Data_Fetcher",
#             system_message="You are responsible for fetching historical stock data from Yahoo Finance. "
#                            "You will receive a stock ticker and download its data for the last year. "
#                            "Save the data as a CSV file. Inform the user of the file path.",
#             llm_config={"config_list": [{"model": GEMINI_MODEL, "api_key": GOOGLE_API_KEY}]},
#         )
#
#         fundamental_analyst = autogen.AssistantAgent(
#             name="Fundamental_Analyst",
#             system_message="You are a fundamental stock analyst. "
#                            "You will receive historical stock data (likely in CSV format). "
#                            "Analyze key financial metrics and provide an opinion on whether the stock is a good long-term investment. "
#                            "Focus on profitability, growth, valuation, and financial health. "
#                            "Use Gemini to help interpret the data and provide insights. "
#                            "Do not perform technical analysis. Output your findings clearly, including a recommendation (Invest/Do Not Invest/Hold) and a brief explanation.",
#             llm_config={"config_list": [{"model": GEMINI_MODEL, "api_key": GOOGLE_API_KEY}]},
#         )
#
#         technical_analyst = autogen.AssistantAgent(
#             name="Technical_Analyst",
#             system_message="You are a technical stock analyst. "
#                            "You will receive historical stock data. "
#                            "Calculate and analyze key technical indicators: RSI, MACD, 50-day Moving Average (MA), 200-day MA, Supertrend, and Price/Volume action. "
#                            "Use the 'pandas_ta' library for calculations. "
#                            "Based on these indicators, provide a short-term to mid-term investment recommendation (Buy/Sell/Hold) and explain the reasoning. "
#                            "Focus on trends, momentum, and support/resistance levels. "
#                            "Use Gemini to help interpret the indicators and provide actionable insights. "
#                            "Do not perform fundamental analysis. Output your findings clearly.",
#             llm_config={"config_list": [{"model": GEMINI_MODEL, "api_key": GOOGLE_API_KEY}]},
#         )
#
#         investment_strategy_agent = autogen.AssistantAgent(
#             name="Investment_Strategy_Agent",
#             system_message="You are an investment strategist. "
#                            "You will receive the fundamental analysis and technical analysis reports for a stock. "
#                            "Based on both analyses, decide if the stock is worth investing in. "
#                            "If it is, suggest an appropriate entry level and exit level. "
#                            "If it's not worth investing, clearly state that. "
#                            "Your final output should be a consolidated investment recommendation with entry/exit points (if applicable) and a clear justification. "
#                            "Use Gemini to synthesize the information and provide strategic recommendations.",
#             llm_config={"config_list": [{"model": GEMINI_MODEL, "api_key": GOOGLE_API_KEY}]},
#         )
#
#         # --- Main execution logic ---
#
#         def analyze_stock(stock_ticker):
#             print(f"\n{'='*30} Starting analysis for stock: {stock_ticker} {'='*30}\n")
#
#             if GOOGLE_API_KEY is None:
#                 print("Cannot proceed without Google API Key. Please set it.")
#                 return
#
#             # --- Task 1: Fetch Data ---
#             user_proxy.initiate_chat(
#                 data_fetcher,
#                 message=f"Please download historical data for stock ticker: {stock_ticker} for the last year and save it as a CSV file. "
#                         "Once done, inform me about the file name and location.",
#                 summary_method="last",
#             )
#
#             data_file_path = os.path.join("stock_analysis_output", f"{stock_ticker.upper()}_data.csv")
#             if not os.path.exists(data_file_path):
#                 print(f"Error: Data file not found at {data_file_path}. Analysis cannot proceed.")
#                 return
#
#             print(f"\nData fetched and saved to: {data_file_path}\n")
#
#             # --- Task 2: Fundamental and Technical Analysis (Initiated by User_Proxy) ---
#             # We simulate the handoff by having user_proxy send messages to other agents.
#
#             # Fundamental Analysis
#             user_proxy.initiate_chat(
#                 fundamental_analyst,
#                 message=f"Please perform fundamental analysis on the stock data provided in the file: {data_file_path}. "
#                         "Output your findings and investment recommendation.",
#                 summary_method="last",
#                 silent=True
#             )
#             fundamental_report = user_proxy.last_message(fundamental_analyst)
#
#             # Technical Analysis
#             user_proxy.initiate_chat(
#                 technical_analyst,
#                 message=f"Please perform technical analysis on the stock data provided in the file: {data_file_path}. "
#                         "Calculate RSI, MACD, 50/200 DMA, Supertrend, and Price/Volume action. "
#                         "Provide your investment recommendation and reasoning.",
#                 summary_method="last",
#                 silent=True
#             )
#             technical_report = user_proxy.last_message(technical_analyst)
#
#             # --- Task 3: Consolidate and Strategize ---
#             combined_analysis_message = f"Here are the analysis reports:\n\n" \
#                                         f"**Fundamental Analysis Report:**\n{fundamental_report}\n\n" \
#                                         f"**Technical Analysis Report:**\n{technical_report}\n\n" \
#                                         f"Please consolidate these findings and provide a final investment strategy, including entry and exit levels if the stock is deemed investable."
#
#             user_proxy.initiate_chat(
#                 investment_strategy_agent,
#                 message=combined_analysis_message,
#                 summary_method="last",
#             )
#             final_recommendation = user_proxy.last_message(investment_strategy_agent)
#
#             print("\n" + "="*50)
#             print(f"FINAL INVESTMENT RECOMMENDATION for {stock_ticker}:")
#             print("="*50)
#             print(final_recommendation)
#             print("="*50)
#
#         # --- Interactive Input ---
#         # This part will prompt you for the stock ticker when the cell is executed.
#         stock_to_analyze = input("Please enter the stock ticker you want to analyze (e.g., AAPL, MSFT, GOOG): ").strip().upper()
#         if stock_to_analyze:
#             analyze_stock(stock_to_analyze)
#         else:
#             print("No stock ticker provided. Exiting.")
#
#         ```
#         Run this cell. It will ask for a stock ticker in the input field below the cell.
#
# This setup ensures that AutoGen agents are used, they leverage Google Gemini for analysis and decision-making, and `yfinance` combined with `pandas_ta` handles data fetching and technical indicators without installation issues. The workflow is orchestrated by the `User_Proxy` agent.
#
# TERMINATE
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-27-3986109824.py in <cell line: 0>()
#      60 chat_id = chat_response.chat_id
#      61 convs = chat_response.chat_history
# ---> 62 total_cost = chat_response.cost[1]
#      63
#      64 print(f"CHAT REF: {chat_id}")
#
# KeyError: 1
